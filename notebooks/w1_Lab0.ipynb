# %% [markdown]
# ## LABORATORIO 0 - ENVÍO DE NOTEBOOKS
# # Curso: Series de Tiempo
# # Profesor: Jonathan Acosta
# # Objetivo: Practicar el formato de entrega de tareas en Jupyter Notebook

# %% [markdown]
# ## 🧪 Laboratorio 0: Enviando tu primer notebook.
#
# # Bienvenid@ al curso de Series de Tiempo.
#
# # Este laboratorio tiene como único propósito que practiques el **formato de entrega**.
# # No será evaluado por su contenido, sino por tu correcta ejecución y envío.
#
# # Asegúrate de seguir todas las instrucciones, ejecutar todas las celdas y guardar tu archivo.

# %%
# Cargaremos las librerías necesarias para este notebook.
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings('ignore')
warnings.warn('DelftStack')
warnings.warn('Do not show this message')

# %% [markdown]
# ## 🧮 Operaciones matemáticas simples
#
#  **Instrucción:**
# Define dos variables $a$ y $b$ con valores **15** y **4**. Luego crea una variable $suma$ que contenga su suma.

# %%
# your code here
a = 15
b = 4
suma = a + b

# %% [markdown]
# ## 📈 Gráfico básico
#
#  **Instrucción:**
# Grafica la función cuadrática $y=x^2$ para $ x \in [-10, 10]$

# %%
# Guardar respuesta:
# respuesta: indicar la respuesta a la pregunta

# your code here
x = np.linspace(-10, 10, 500)
y = x**2

plt.figure(figsize=(8, 5))
plt.plot(x, y)

plt.title("Gráfico de la función y = x²")
plt.xlabel("x")
plt.ylabel("y")

plt.show()

# %% [markdown]
# # **Pregunta:**
# ¿Qué función representa el gráfico anterior?
# Responda en términos algebraicos, por ejemplo: log(x)
# Crea la variable respuesta_1 con tu respuesta.

# %%
# your code here
respuesta_1 = "x^2"

# %% [markdown]
# ## ❓Pregunta de opción única
#
# # **Pregunta:**
# # ¿Cuál de las siguientes afirmaciones es **verdadera**?
#
# * 1. Las series de tiempo no dependen del tiempo.
# * 2. Una serie de tiempo es una secuencia de observaciones ordenadas en el tiempo.
# * 3. Una serie de tiempo siempre tiene valores negativos.
#
#  **Selecciona la correcta y escribe la oración completa en la variable respuesta_2**

# %%
# your code here
respuesta_2 = "Una serie de tiempo es una secuencia de observaciones ordenadas en el tiempo."

# %%
# Prueba oculta: Check del modelo

# %% [markdown]
# ## 📤Entrega
#
# * Asegúrate de que **todas las celdas** se ejecuten correctamente (sin errores).
# * Este laboratorio **no tiene nota**, pero es **requisito obligatorio** para continuar con los siguientes laboratorios del curso.
